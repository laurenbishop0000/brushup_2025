# %% [markdown]
# <a href="https://colab.research.google.com/github/laurenbishop0000/brushup_2025/blob/main/Colab_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to import data into Google Collab

# %% [markdown]
# ## Option 1: mounting google drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# adjust the link in accordance to where you uploaded the csv - make sure that it's not a version you opened in google sheets but the original csv simply uploaded

import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/EconAI_private/Teaching/Brushup_DSDM/data/WB_pop_clean.csv')

#df = pd.read_csv('/content/drive/MyDrive/WB_pop_clean.csv')

# %%
df
# Out:
#            Series Name  Series Code        Country Name Country Code  \
# 0    Population, total  SP.POP.TOTL         Afghanistan          AFG
# 1    Population, total  SP.POP.TOTL             Albania          ALB
# 2    Population, total  SP.POP.TOTL             Algeria          DZA
# 3    Population, total  SP.POP.TOTL      American Samoa          ASM
# 4    Population, total  SP.POP.TOTL             Andorra          AND
# ..                 ...          ...                 ...          ...
# 213  Population, total  SP.POP.TOTL  West Bank and Gaza          PSE
# 214  Population, total  SP.POP.TOTL         Yemen, Rep.          YEM
# 215  Population, total  SP.POP.TOTL              Zambia          ZMB
# 216  Population, total  SP.POP.TOTL            Zimbabwe          ZWE
# 217  Population, total  SP.POP.TOTL               World          WLD
#
#            2001        2002        2003        2011        2012        2013  \
# ...

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ## Option 2: via GoogleCredentials

# %%
# Install the required libraries
#!pip install gspread google-auth

# Import libraries
import gspread
from gspread_dataframe import get_as_dataframe
from google.colab import auth
from oauth2client.client import GoogleCredentials
from google.auth import default
import pandas as pd

# Authenticate and create a client
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# %%
# take the excel spreadsheet with mutiple worksheet tabs that I shared, upload/ add it to your drive and OPEN IT IN & SAVE AS GOOGLE SHEET.
# then paste the link to that sheet here:

#spreadsheet_url = 'https://docs.google.com/spreadsheets/d/13IZxy4XwbQ7dXxGmj0ODostAD_mJf9S3rhHXrdYtO0I/edit?gid=238107633#gid=238107633'
#spreadsheet_url =  'https://docs.google.com/spreadsheets/d/13IZxy4XwbQ7dXxGmj0ODostAD_mJf9S3rhHXrdYtO0I/edit?gid=0#gid=0'
spreadsheet_url =  'https://docs.google.com/spreadsheets/d/13IZxy4XwbQ7dXxGmj0ODostAD_mJf9S3rhHXrdYtO0I/edit?usp=sharing'

# Open the spreadsheet
spreadsheet = gc.open_by_url(spreadsheet_url)

# %%
# Get all the worksheet objects (tabs) in the spreadsheet
worksheets = spreadsheet.worksheets()

# Create a dictionary of DataFrames for each sheet
dfs = {}
for sheet in worksheets:
    sheet_name = sheet.title
    df = get_as_dataframe(sheet)
    dfs[sheet_name] = df

# Print the names of the sheets and their respective DataFrame head
for sheet_name, df in dfs.items():
    print(f"name of sheet: {sheet_name}")
    #print(df.head())  # Show first few rows of each DataFrame - NB it contains tons of NaNs
# Out:
# name of sheet: name1
# name of sheet: name2

# %%
df1 = dfs['name1']
print('initial shape:', df1.shape)
df1 = df1.loc[:,~df1.columns.str.match("Unnamed")]
print('after removing unndamed columns: ', df1.shape)
df1 = df1.dropna()
print('after removing rows with NaNs: ', df1.shape)
df1
# Out:
# initial shape: (4, 3)
# after removing unndamed columns:  (4, 3)
# after removing rows with NaNs:  (4, 3)
#      col_1  col_2  col_3
# 0     some   33.0    2.4
# 1  random    44.0    3.5
# 2    text    55.0    4.6
# 3     data   66.0    5.7

# %%
df2 = dfs['name2']
print('initial shape:', df2.shape)
df2 = df2.loc[:,~df2.columns.str.match("Unnamed")]
print('after removing unndamed columns: ', df2.shape)
df2 = df2.dropna()
print('after removing rows with NaNs: ', df2.shape)
df2
# Out:
# initial shape: (4, 3)
# after removing unndamed columns:  (4, 3)
# after removing rows with NaNs:  (4, 3)
#    col_1  col_2  col_3
# 0     a    77.0    1.2
# 1    bit   88.0    6.7
# 2  more    99.0    7.8
# 3   text  100.0    8.9

# %% [markdown]
# ## Option 3: via external database - Dropbox

# %%
# NB, you need to change the =0 at the end of the original linkto =1

more_data = pd.read_csv('https://www.dropbox.com/scl/fi/izex86axu76nlyv049idr/WB_more_data.csv?rlkey=68cm1vd4yzk8ea7i77b5qk1db&st=s9hdvdgs&dl=1')
more_data
# Out:
#                           Series Name     Series Code           Country Name  \
# 0                   Population, total     SP.POP.TOTL            Afghanistan
# 1                   Population, total     SP.POP.TOTL                Albania
# 2                   Population, total     SP.POP.TOTL                Algeria
# 3                   Population, total     SP.POP.TOTL         American Samoa
# 4                   Population, total     SP.POP.TOTL                Andorra
# ...                               ...             ...                    ...
# 1080  GNI, Atlas method (current US$)  NY.GNP.ATLS.CD  Virgin Islands (U.S.)
# 1081  GNI, Atlas method (current US$)  NY.GNP.ATLS.CD     West Bank and Gaza
# 1082  GNI, Atlas method (current US$)  NY.GNP.ATLS.CD            Yemen, Rep.
# 1083  GNI, Atlas method (current US$)  NY.GNP.ATLS.CD                 Zambia
# 1084  GNI, Atlas method (current US$)  NY.GNP.ATLS.CD               Zimbabwe
#
# ...
